# %%
import numpy as np
import qu_decomp as qu
import os_plot as os

# %%
a = np.array([(1,2),(3,4)])
a
if a.shape == (3, 2):
    print(a.shape)
a[:,0]
# Out:
# array([1, 3])

# %%
matrix = np.array([(1,1),(2,0)])
Q = np.zeros(shape=(2,2))
U = np.zeros(shape = (2,2))
c_1 = matrix[:,0]
c_2 = matrix[:,1]
        
f_1 = c_1
f_2 = c_2 - ((np.dot(c_2, f_1)/(np.linalg.norm(f_1))**2)*f_1)

q_1 = f_1/np.linalg.norm(f_1)
q_2 = f_2/np.linalg.norm(f_2)
        
Q[:,0] = q_1
Q[:,1] = q_2
        
U[0,0] = np.linalg.norm(f_1)
U[0,1] = np.dot(c_2, q_1)
U[1,1] = np.linalg.norm(f_2)

A = np.dot(U, Q)
A
# Out:
# array([[ 1.4,  1.8],
#        [ 0.8, -0.4]])

# %%
matrix = np.array([(10,3),(5,-10)])
A = qu.calculate(matrix, max_it = 100, acceptance = 0.001, print_conv = True, save_folder='C:/Users/bryce/Downloads', savefilename='convergence')
# Out:
# No convergence reached after maximum number of iterations, consider increasing the maximum iterations, the acceptance value, or printing the convergence to examine the chains
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Final Eigenvalues of the last iteration:
# Eigenvalue 1 = 10.0
# Eigenvalue 2 = -10.0
# ---------------------------------
# Final Matrix:
# [[ 10.   3.]
#  [  5. -10.]]

# %%
mass_range = np.geomspace(1,100,100)
mass_range = np.array(mass_range)
mass2_range = np.geomspace(100,1,100)
os.mass_plot(mass_range, 10, mass2_range = mass2_range)

# %%
spring_const_range = np.geomspace(1,100,100)
os.spring_const_plot(spring_const_range, 10)
