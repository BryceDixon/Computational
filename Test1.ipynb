# %%
import numpy as np
import qu_decomp as qu
import os_plot as os

# %%
a = np.array([(1,2),(3,4)])
a
if a.shape == (3, 2):
    print(a.shape)
a[:,0]
# Out:
# array([1, 3])

# %%
matrix = np.array([(1,1),(2,0)])
Q = np.zeros(shape=(2,2))
U = np.zeros(shape = (2,2))
c_1 = matrix[:,0]
c_2 = matrix[:,1]
        
f_1 = c_1
f_2 = c_2 - ((np.dot(c_2, f_1)/(np.linalg.norm(f_1))**2)*f_1)

q_1 = f_1/np.linalg.norm(f_1)
q_2 = f_2/np.linalg.norm(f_2)
        
Q[:,0] = q_1
Q[:,1] = q_2
        
U[0,0] = np.linalg.norm(f_1)
U[0,1] = np.dot(c_2, q_1)
U[1,1] = np.linalg.norm(f_2)

A = np.dot(U, Q)
A
# Out:
# array([[ 1.4,  1.8],
#        [ 0.8, -0.4]])

# %%
matrix = np.array([(2,3,5,5),(6,-2,4,3),(0,0,4,3),(0,0,2,6)])
A = qu.calculate(matrix, max_it = 100, acceptance = 0.001, print_conv = True, save_folder='C:/Users/bryce/Downloads', savefilename='convergence')
# Out:
# No convergence reached after maximum number of iterations, consider increasing the maximum iterations, the acceptance value, or printing the convergence to examine the chains
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Final Eigenvalues of the last iteration:
# Eigenvalue 1 = 2.0
# Eigenvalue 2 = -2.0
# Eigenvalue 3 = 7.646
# Eigenvalue 4 = 2.354
# ---------------------------------
# Final Matrix:
# [[ 2.     3.     7.038 -0.684]
#  [ 6.    -2.     4.858 -1.182]
#  [ 0.     0.     7.646  1.   ]
#  [ 0.     0.     0.     2.354]]

# %%
mass_range = np.linspace(1,100,100)
mass_range = np.array(mass_range)
mass2_range = np.geomspace(1,100,100)*2
mass2_range = [10]*100
os.mass_plot(mass_range, 10, mass2_range = mass_range*1000, analytical = True, save_folder='C:/Users/bryce/Downloads', savefilename='10m2_mass_plot')

# %%
spring_const_range = np.geomspace(1,100,100)
os.spring_const_plot(spring_const_range, 10, analytical = True, save_folder='C:/Users/bryce/Downloads', savefilename='spring_const_plot')

# %%
mass_range = np.linspace(1,100,100)
mass2_range = [100]*100
spring_const = 10
A = []
for i in range(len(mass_range)):
    m_r = (mass_range[i]+mass2_range[i])/(mass_range[i]*mass2_range[i])
    A.append(np.sqrt(spring_const*m_r-np.sqrt((spring_const**2) * (m_r**2) - ((3*spring_const**2)/(mass_range[i]*mass2_range[i])))))
A

mass_range = np.linspace(1,100,100)
mass2_range = mass_range
spring_const = 10
B = []
for i in range(len(mass_range)):
    m_r = (mass_range[i]+mass2_range[i])/(mass_range[i]*mass2_range[i])
    B.append(np.sqrt(spring_const*m_r+np.sqrt((spring_const**2) * (m_r**2) - ((3*spring_const**2)/(mass_range[i]*mass2_range[i])))))
B
A = np.array(A)
B = np.array(B)
C = A-B
A
# Out:
# array([0.38681148, 0.38631915, 0.38582129, 0.38531788, 0.38480888,
#        0.38429425, 0.38377398, 0.38324804, 0.38271639, 0.38217901,
#        0.38163589, 0.38108701, 0.38053234, 0.37997187, 0.3794056 ,
#        0.37883352, 0.37825561, 0.37767188, 0.37708233, 0.37648696,
#        0.37588578, 0.37527879, 0.37466602, 0.37404748, 0.37342318,
#        0.37279316, 0.37215744, 0.37151605, 0.37086902, 0.3702164 ,
#        0.36955823, 0.36889456, 0.36822543, 0.3675509 , 0.36687102,
#        0.36618586, 0.36549549, 0.36479997, 0.36409938, 0.3633938 ,
#        0.3626833 , 0.36196797, 0.3612479 , 0.36052318, 0.3597939 ,
#        0.35906016, 0.35832208, 0.35757974, 0.35683326, 0.35608274,
#        0.35532831, 0.35457008, 0.35380816, 0.35304268, 0.35227376,
#        0.35150153, 0.35072611, 0.34994763, 0.34916623, 0.34838202,
#        0.34759516, 0.34680577, 0.34601398, 0.34521993, 0.34442376,
#        0.3436256 , 0.34282559, 0.34202387, 0.34122057, 0.34041583,
#        0.33960978, 0.33880257, 0.33799431, 0.33718515, 0.33637522,
#        0.33556465, 0.33475357, 0.33394211, 0.33313039, 0.33231853,
#        0.33150667, 0.33069492, 0.32988341, 0.32907224, 0.32826154,
#        0.32745141, 0.32664197, 0.32583333, 0.32502559, 0.32421886,
#        0.32341323, 0.3226088 , 0.32180568, 0.32100395, 0.32020371,
#        0.31940504, 0.31860803, 0.31781276, 0.31701931, 0.31622777])
